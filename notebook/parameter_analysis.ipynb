# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
parameter_analysis = pd.read_csv('../data/credibility_withoutUser_Count_.csv', sep=',')
parameter_analysis = parameter_analysis.drop(columns=['Unnamed: 4', 'Unnamed: 5'])
parameter_analysis
# Out:
#       Node  credibility-WithoutUsercount  credibility-whioutDatabyte  \
# 0      6.0                  1.422000e-07                5.687688e-09
# 1      8.0                  8.728777e-02                3.491319e-03
# 2     10.0                  1.108600e-04                4.434157e-06
# 3     12.0                  4.411000e-07                1.764303e-08
# 4     23.0                  1.347446e-02                5.389490e-04
# ...    ...                           ...                         ...
# 1935   NaN                           NaN                9.600270e-01
# 1936   NaN                           NaN                9.660911e-01
# 1937   NaN                           NaN                9.703124e-01
# 1938   NaN                           NaN                9.815814e-01
# 1939   NaN                           NaN                9.930220e-01
#
#       credibility-withoutline
# 0                6.086776e-09
# 1                3.736295e-03
# 2                4.745288e-06
# 3                1.888099e-08
# 4                5.767655e-04
# ...                       ...
# 1935             9.715334e-01
# 1936             9.773608e-01
# 1937             9.807933e-01
# 1938             9.923723e-01
# 1939             9.930019e-01
#
# [1940 rows x 4 columns]

# %%
parameter_analysis.columns

parameter_analysis['credibility-withoutline'] = parameter_analysis['credibility-withoutline'].astype('float64').apply(lambda x: x*1/parameter_analysis['credibility-withoutline'].max())
parameter_analysis['credibility-whioutDatabyte'] = parameter_analysis['credibility-whioutDatabyte'].astype('float64').apply(lambda x: x*1/parameter_analysis['credibility-whioutDatabyte'].max())
parameter_analysis['credibility-WithoutUsercount'] = parameter_analysis['credibility-WithoutUsercount'].astype('float64').apply(lambda x: x*1/parameter_analysis['credibility-WithoutUsercount'].max())


parameter_analysis['credibility-withoutline'].max()
# parameter_analysis['credibility-whioutDatabyte'].max()
# parameter_analysis['credibility-WithoutUsercount'].max()
# Out:
# 1.0

# %%
plt.scatter(parameter_analysis['credibility-withoutline'], parameter_analysis['credibility-whioutDatabyte'], c='red', label='credibility-whioutDatabyte')
plt.scatter(parameter_analysis['credibility-withoutline'], parameter_analysis['credibility-WithoutUsercount'], c='blue', label='credibility-WithoutUsercount')
plt.scatter(parameter_analysis['credibility-withoutline'], parameter_analysis['credibility-withoutline'], c='green', label='credibility-withoutline')
plt.xlabel('credibility-withoutline')
plt.ylabel('credibility')
plt.legend()
plt.show()
