# %%
import seaborn as sns
import numpy as np

# %%
# 1      16745 50633 22199 
# 16745  1     57063 22874 2
# 50633  57063 1     16745 0
# 22199  22874 16745 1     0
# 0      2     0     0     1

# make a 2D array
data = np.array([[57063, 16745, 50633, 22199, 5656], [16745, 57063, 57063, 22874, 8974], [50633, 57063, 57063, 16745, 2165], [22199, 22874, 16745, 57063, 1654], [5656, 8974, 2165, 1654, 57063]])

## divide data by 57063
# data = data / 57063

## make a heatmap purple color
sns.heatmap(data, annot=True, cmap='Purples')
# sns.heatmap(data, annot=True, cmap='YlGnBu')

import matplotlib.pyplot as plt
plt.show()
